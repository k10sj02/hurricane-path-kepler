# %% [markdown]
# <a href="https://colab.research.google.com/github/k10sj02/hurricane-path-kepler/blob/main/hurricane_tracks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()

df = pd.read_csv('storms.csv')
# Out:
#      <input type="file" id="files-996fd93e-ec46-4c4f-8957-4385c8c236e8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-996fd93e-ec46-4c4f-8957-4385c8c236e8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df
# Out:
#                       name  year  month  day  hour   lat  long  \
# 0                 AL011975  1975      6   24    12  32.5 -52.0
# 1                 AL011975  1975      6   24    18  32.6 -52.6
# 2                 AL011975  1975      6   25     0  32.7 -53.2
# 3                 AL011975  1975      6   25    60  32.8 -53.2
# 4                 AL011975  1975      6   25    12  33.0 -54.5
# ...                    ...   ...    ...  ...   ...   ...   ...
# 22700                 Sara  2024     11   17    60  16.5 -87.5
# 22701                 Sara  2024     11   17    12  16.8 -87.9
# 22702                 Sara  2024     11   17    14  17.0 -88.3
# 22703                 Sara  2024     11   17    18  17.4 -89.1
# 22704                 Sara  2024     11   18     0  17.9 -90.2
#
#                     status  category  wind  pressure  \
# 0      tropical depression       NaN    20      -999
# 1      tropical depression       NaN    25      -999
# ...

# %%
import pandas as pd

df['date'] = pd.to_datetime(dict(year=df.year, month=df.month, day=df.day, hour=df.hour))
df.insert(5, 'date', df.pop('date'))

df
# Out:
#                       name  year  month  day  hour                date   lat  \
# 0                 AL011975  1975      6   24    12 1975-06-24 12:00:00  32.5
# 1                 AL011975  1975      6   24    18 1975-06-24 18:00:00  32.6
# 2                 AL011975  1975      6   25     0 1975-06-25 00:00:00  32.7
# 3                 AL011975  1975      6   25    60 1975-06-27 12:00:00  32.8
# 4                 AL011975  1975      6   25    12 1975-06-25 12:00:00  33.0
# ...                    ...   ...    ...  ...   ...                 ...   ...
# 22700                 Sara  2024     11   17    60 2024-11-19 12:00:00  16.5
# 22701                 Sara  2024     11   17    12 2024-11-17 12:00:00  16.8
# 22702                 Sara  2024     11   17    14 2024-11-17 14:00:00  17.0
# 22703                 Sara  2024     11   17    18 2024-11-17 18:00:00  17.4
# 22704                 Sara  2024     11   18     0 2024-11-18 00:00:00  17.9
#
# ...

# %%
df.to_csv('storms_tidy.csv', index=False)
from google.colab import files
files.download('storms_tidy.csv')
